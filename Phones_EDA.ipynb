# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data=pd.read_csv("C:/Users/HP/Downloads/phones_data.csv")

# %%
#1 undertsanding data

# %%
data.head()
# Out:
#    Unnamed: 0 brand_name                                    model_name  \
# 0           0    ALCATEL          1 1/8GB Bluish Black (5033D-2JALUAA)
# 1           1    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 2           2    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 3           3    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 4           4      Nokia                           1.3 1/16GB Charcoal
#
#         os  popularity  best_price  lowest_price  highest_price  \
# 0  Android         422      1690.0        1529.0         1819.0
# 1  Android         323      1803.0        1659.0         2489.0
# 2  Android         299      1803.0        1659.0         2489.0
# 3  Android         287      1803.0        1659.0         2489.0
# 4  Android        1047      1999.0           NaN            NaN
#
#    sellers_amount  screen_size  memory_size  battery_size release_date
# 0              36         5.00          8.0        2000.0      10-2020
# ...

# %%
data.tail()
# Out:
#       Unnamed: 0    brand_name                                model_name  \
# 1219        1219         Apple           iPhone XS Max 64GB Gold (MT522)
# 1220        1220         Apple  iPhone XS Max Dual Sim 64GB Gold (MT732)
# 1221        1221        HUAWEI          nova 5T 6/128GB Black (51094MEU)
# 1222        1222           ZTE          nubia Red Magic 5G 8/128GB Black
# 1223        1223  Sigma mobile                         x-style 35 Screen
#
#            os  popularity  best_price  lowest_price  highest_price  \
# 1219      iOS        1101     22685.0       16018.0        27900.0
# 1220      iOS         530     24600.0       21939.0        33720.0
# 1221  Android        1174      8804.0        7999.0         9999.0
# 1222  Android         752     18755.0       18500.0        19010.0
# 1223      NaN         952       907.0         785.0          944.0
#
#       sellers_amount  screen_size  memory_size  battery_size release_date
# ...

# %%
data.shape
# Out:
# (1224, 13)

# %%
data.describe()
# Out:
#         Unnamed: 0   popularity    best_price  lowest_price  highest_price  \
# count  1224.000000  1224.000000   1224.000000    964.000000     964.000000
# mean    611.500000   612.500000   7941.206699   7716.018672    9883.410788
# std     353.482673   353.482673   8891.836260   8560.959059   11514.936818
# min       0.000000     1.000000    214.000000    198.000000     229.000000
# 25%     305.750000   306.750000   2599.750000   2399.000000    2887.000000
# 50%     611.500000   612.500000   4728.000000   4574.000000    5325.500000
# 75%     917.250000   918.250000   9323.000000   9262.250000   12673.750000
# max    1223.000000  1224.000000  56082.000000  49999.000000   69999.000000
#
#        sellers_amount  screen_size  memory_size  battery_size
# count     1224.000000  1222.000000  1112.000000   1214.000000
# mean        16.743464     5.394378    95.700059   3608.201812
# std         20.597006     1.476991   111.922576   1668.268774
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'brand_name', 'model_name', 'os', 'popularity',
#        'best_price', 'lowest_price', 'highest_price', 'sellers_amount',
#        'screen_size', 'memory_size', 'battery_size', 'release_date'],
#       dtype='object')

# %%
data.nunique()
# Out:
# Unnamed: 0        1224
# brand_name          64
# model_name        1068
# os                   6
# popularity        1224
# best_price         970
# lowest_price       666
# highest_price      648
# sellers_amount      94
# screen_size         82
# memory_size         15
# battery_size       151
# release_date        73
# dtype: int64

# %%
data['memory_size'].unique()
# Out:
# array([8.00e+00, 1.60e+01, 6.40e+01, 3.20e+01, 1.28e+02, 4.00e-03,
#             nan, 1.60e-02, 4.00e+00, 2.56e+02, 3.20e-02, 6.40e-02,
#        5.12e+02, 1.00e+03, 3.20e-03, 1.28e-01])

# %%
#cleaning the data base

# %%
data.isnull().sum()
# Out:
# Unnamed: 0          0
# brand_name          0
# model_name          0
# os                197
# popularity          0
# best_price          0
# lowest_price      260
# highest_price     260
# sellers_amount      0
# screen_size         2
# memory_size       112
# battery_size       10
# release_date        0
# dtype: int64

# %%
data.dropna()
# Out:
#       Unnamed: 0 brand_name                                    model_name  \
# 0              0    ALCATEL          1 1/8GB Bluish Black (5033D-2JALUAA)
# 1              1    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 2              2    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 3              3    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 5              5      Honor                               10 6/64GB Black
# ...          ...        ...                                           ...
# 1218        1218      Apple        iPhone XS Max 512GB Space Gray (MT622)
# 1219        1219      Apple               iPhone XS Max 64GB Gold (MT522)
# 1220        1220      Apple      iPhone XS Max Dual Sim 64GB Gold (MT732)
# 1221        1221     HUAWEI              nova 5T 6/128GB Black (51094MEU)
# 1222        1222        ZTE              nubia Red Magic 5G 8/128GB Black
#
#            os  popularity  best_price  lowest_price  highest_price  \
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0          0
# brand_name          0
# model_name          0
# os                197
# popularity          0
# best_price          0
# lowest_price      260
# highest_price     260
# sellers_amount      0
# screen_size         2
# memory_size       112
# battery_size       10
# release_date        0
# dtype: int64

# %%
data.dropna(how='all')
# Out:
#       Unnamed: 0    brand_name                                    model_name  \
# 0              0       ALCATEL          1 1/8GB Bluish Black (5033D-2JALUAA)
# 1              1       ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 2              2       ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 3              3       ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 4              4         Nokia                           1.3 1/16GB Charcoal
# ...          ...           ...                                           ...
# 1219        1219         Apple               iPhone XS Max 64GB Gold (MT522)
# 1220        1220         Apple      iPhone XS Max Dual Sim 64GB Gold (MT732)
# 1221        1221        HUAWEI              nova 5T 6/128GB Black (51094MEU)
# 1222        1222           ZTE              nubia Red Magic 5G 8/128GB Black
# 1223        1223  Sigma mobile                             x-style 35 Screen
#
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0          0
# brand_name          0
# model_name          0
# os                197
# popularity          0
# best_price          0
# lowest_price      260
# highest_price     260
# sellers_amount      0
# screen_size         2
# memory_size       112
# battery_size       10
# release_date        0
# dtype: int64

# %%
new_data=data.dropna(axis=0,how='any')

# %%
new_data.head()
# Out:
#    Unnamed: 0 brand_name                                    model_name  \
# 0           0    ALCATEL          1 1/8GB Bluish Black (5033D-2JALUAA)
# 1           1    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 2           2    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 3           3    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 5           5      Honor                               10 6/64GB Black
#
#         os  popularity  best_price  lowest_price  highest_price  \
# 0  Android         422      1690.0        1529.0         1819.0
# 1  Android         323      1803.0        1659.0         2489.0
# 2  Android         299      1803.0        1659.0         2489.0
# 3  Android         287      1803.0        1659.0         2489.0
# 5  Android          71     10865.0       10631.0        11099.0
#
#    sellers_amount  screen_size  memory_size  battery_size release_date
# 0              36          5.0          8.0        2000.0      10-2020
# ...

# %%
new_data.isnull().sum()
# Out:
# Unnamed: 0        0
# brand_name        0
# model_name        0
# os                0
# popularity        0
# best_price        0
# lowest_price      0
# highest_price     0
# sellers_amount    0
# screen_size       0
# memory_size       0
# battery_size      0
# release_date      0
# dtype: int64

# %%
phones_data=data.drop(['Unnamed: 0','brand_name','model_name','popularity','release_date'],axis=1)

# %%
phones_data.head()
# Out:
#         os  best_price  lowest_price  highest_price  sellers_amount  \
# 0  Android      1690.0        1529.0         1819.0              36
# 1  Android      1803.0        1659.0         2489.0              36
# 2  Android      1803.0        1659.0         2489.0              36
# 3  Android      1803.0        1659.0         2489.0              36
# 4  Android      1999.0           NaN            NaN              10
#
#    screen_size  memory_size  battery_size
# 0         5.00          8.0        2000.0
# 1         5.00         16.0        2000.0
# 2         5.00         16.0        2000.0
# 3         5.00         16.0        2000.0
# 4         5.71         16.0        3000.0

# %%
#3 relationship analysis

# %%
corelation=phones_data.corr()

# %%
sns.heatmap(corelation,xticklabels=corelation.columns,yticklabels=corelation.columns,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(phones_data)

# %%
sns.relplot(x='best_price',y='sellers_amount',hue='os',data=phones_data)

# %%
sns.relplot(x='best_price',y='sellers_amount',hue='battery_size',data=phones_data)

# %%
sns.relplot(x='best_price',y='sellers_amount',hue='memory_size',data=phones_data)

# %%
sns.relplot(x='best_price',y='sellers_amount',hue='screen_size',data=phones_data)

# %%
sns.distplot(phones_data['best_price'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='best_price', ylabel='Density'>

# %%
sns.distplot(phones_data['sellers_amount'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sellers_amount', ylabel='Density'>

# %%
sns.catplot(x='best_price',kind='box',data=phones_data)

# %%
sns.catplot(x='sellers_amount',kind='box',data=phones_data)
